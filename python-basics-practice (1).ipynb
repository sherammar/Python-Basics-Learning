# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# printing out the statement
print("Hello Notebook")

# %%
#initializing variables, inserting values and then printing out
name = "John Smith" 
age = 24
is_new = True
print(name, age, is_new)

# %% [markdown]
# **Practice questions for object string and it's methods**

# %%
# Taking input from user and converting the string to uppercase
name = input("Enter Your name: ").upper()
print("Hello", name)

# %%
# Question: Given a string text = "programming", print the first 5 characters.
text = "programming"
print(text[:5])

# %%
# Question: Count how many times the letter "a" appears in text = "banana"
text = "banana"
letter = "a"
letter_appearance_counter = text.count(letter)

# Alternative approach
letter_appearance_counter_alt = text.count("a")

print(letter_appearance_counter)
print(letter_appearance_counter_alt)

# %%
# Question: Convert text = "Python is fun" to uppercase and lowercase.
text = 'Python is fun'
upper_case = text.upper()

lower_case = text.lower()

print(upper_case)

print(lower_case)

# %%
# Question: Reverse the string text = "hello"
text = "hello"
reversed_text = text[::-1]
print(reversed_text)

# Alternative approach
reversed_text_alt = ''.join(reversed(text))
print(reversed_text_alt)

# %%
# Question: Check if the substring "data" is present in sentence = "I love data science"
sentence = "I Love data Science"
substring_check = "data" in sentence
print(substring_check)

# %% [markdown]
# **Practice questions for Integer and Float **

# %%
# Question: Given x = 15 and y = 4, print their division result and remainder.
x = 15
y = 4
result = x / y

# for remainder we will use the modulus operator
remainder = x % y

print(result)
print(remainder)

# %%
# Question: Calculate the area of a circle with radius = 7. (Use π = 3.14).
Pi = 3.14
radius = 7
area = Pi * (radius ** 2)  # exponential
print(area)

# %%
# Question: Find the average of numbers 10, 20, 30, 40, 50.
numbers = 10, 20, 30 ,40, 50
sum_of_numbers = 10 + 20 + 30 + 40 + 50
average = sum_of_numbers / len(numbers)
print(average)

# %%
# Question: Round the float number value = 23.6789 to 2 decimal places.
value = 23.6789

round_value = round(value, 2)

print(round_value)

# %%
# Question: Convert temperature celsius = 37 into Fahrenheit. (Formula: F = (C × 9/5) + 32).
celsius = 37
conv_to_fahrenheit = (celsius * 9/5) + 32
print(conv_to_fahrenheit)

# %% [markdown]
# **Practice Questions for Boolean with conditionals and logic, comparison operators**

# %%
# Question: Let x = 10. Check if x is greater than 5 and less than 20.
x = 10

if x > 5 and x < 20:
    print("Correct!")
else:
    print("Not Correct!")

# %%
# Question: Compare if two strings a = "hello" and b = "Hello" are equal.
a = "hello"
b = "Hello"

if a == b:
    print("Both are Equal!")
else:
    print("Not Equal!")

# %%
# Question: Given num = 17, check if it is odd.
num = 17
if num % 2 == 0:
    print("Even")
else:
    print("Odd")

# %%
# Question: Let age = 20. Check if the person is eligible to vote (18 or older).
age = 20

if age >= 18:
    print("Eligible")
else:
    print("Not Eligible")

# %%
# Question: Given marks = 45, check if the student has passed (pass mark = 40).
marks = 45

if marks >= 40:
    print("Student Passed")
else:
    print("He Passed Away :)")

# %% [markdown]
# # **Practice questions for taking user-input> **

# %%
# Question: Ask the user for their name and then strip the white spaces and print it in uppercase.
name = input("What is Your Name: ").strip().upper()
print("Hello", name)

# %%
# Question: Take an integer input from the user and print whether it is even or odd.
even_or_odd = int(input("Enter the Number: "))

# To check If the number is even or odd we divide the number by 2 check the remainder if it is Zero

if even_or_odd % 2 == 0:
    print("Even")
else:
    print("Odd")

# %%
# Question: Ask the user for a float number and print its square.
float_number = float(input("Enter the number: "))

# using exponential to square the number
square = float_number ** 2
print("Square of the Number is: ", square)

# %%
# Question: Take a user’s age (int) and check if they are eligible to vote (18 or older).
age = int(input("Enter your Age: "))

if age >= 18:
    print("Eligible to Vote")
else:
    print("Not Eligible")

# %%
#Question: Ask the user a yes/no question like "Do you like Python?" and store the answer as a boolean (True if yes, False otherwise).
question = input("Do you like Python? yes/no? ")

if question.lower() == "yes":
    print(True)
else:
    print(False)

# %% [markdown]
# # Practice Questions for type conversion

# %%
# Question: Convert a string "100" into an integer and add 50 to it.

string_number = "100"
print(type(string_number))

# converting the string to int
number = int(string_number)
print(type(number))

# adding 50 to the integer
number += 50
print(number)

# %%
# Question: Convert a float 12.56 into an integer and print the result.
float_number = 12.56
print(type(float_number))

# converting float to int

int_number = int(float_number)
print(type(int_number))

# %%
# Question: Convert an integer 10 into a string and concatenate it with " apples".
int_number = 10
print(type(int_number))

# converting int to str

string_number = str(int_number)
fruit = "apples"

# concatenating the strings and printing out the result
print(string_number + fruit)

# %%
# Question: Convert a boolean True into an integer and a string.
is_boolean = True
print(type(is_boolean))

# converting the boolean to integer
num_boolean = int(is_boolean)
print(type(num_boolean))
print(num_boolean)

# converting the boolean to string

str_boolean = str(is_boolean)
print(type(str_boolean))
print(str_boolean)

# %%
# Questions: Take a number as string input from the user and convert it to a float before multiplying by 2.5.
input = input("Enter the number: ")  # input is string by default because the input() function always return a string
print(type(input))

# converting the str to float

float_number = float(input)
print(type(float_number))

# multiplying the floating number(real number) by 2.5

float_number *= 2
print(float_number)

# %% [markdown]
# # Practice questions for functions

# %%
# Question: Write a function greet(name) that prints "Hello, <name>!".

def greet(name):
    print("Hello ",name)

greet("Ammar Yasir")

# %%
# Question: Write a function square(num) that returns the square of a number.

def square(num):
    num_square = num ** 2
    return num_square

square(3)

# %%
# Question: Write a function is_even(num) that returns True if a number is even, otherwise False.

def is_even(num):
    if num % 2 == 0:
        return True
    else:
        return False
is_even(18)

# %%
# Question: Write a function add_numbers(a, b, c) that returns the sum of three numbers.

def add_numbers(a, b, c):
    sum = a + b + c
    return sum

add_numbers(10, 20 , 30)

# %%
# Question: Write a function calculate_area_circle(radius) that returns the area of a circle (πr², use π = 3.14).

def calculate_area_circle(radius):
    # formula to calculate area of circle is Pi*r**2
    area_of_circle = 3.14 * radius ** 2
    return area_of_circle

calculate_area_circle(9)

# %% [markdown]
# # More questions to practice functions, (No User-Input)

# %%
# Question: Write a function is_positive(num) that returns True if the number is positive, otherwise False.
def is_positive(num):
    if num > 0:
        return True
    else:
        return False
is_positive(-5)
# Out:
# False

# %%
# Question:Write a function count_vowels(text) that returns the number of vowels in a string.
#                       ------My personel approach ------
# def count_vowels(text):
#     vowels = "aeiouAEIOU"
#     count = 0
#     if vowels in text:
#         count += 1
#         return count

# print(count_vowels("ammaryasir"))

# Asked chatgpt for a solution

# First approach without using for loop
def count_vowels(text):
    # using built-in function for counting number of occurence of a character in a string
    count = text.count("a") + text.count("e") + text.count("i") + text.count("o") + text.count("u") + text.count("A") + text.count("E") + text.count("I") + text.count("O") + text.count("U")
    return count

count_vowels("ammar yasir")

# Second approach without using for loop

def count_vowels_alt(text):
    vowels = "aeiouAEIOU"
    total_num_of_vowels = sum(text.count(v) for v in vowels)
    return total_num_of_vowels

count_vowels_alt("ammar yasir")
# Out:
# 4

# %%
# Question: Write a function is_palindrome(word) that returns True if the word is the same forward and backward.

#👉 A palindrome means the word reads the same forwards and backwards (like madam, level, racecar).

#                -----My personel approach-----
# def is_palindrome(word):
#     if word == word[::-1]:  # Reversing the string and check the equality by Boolean(True, False)
#         return True
#     else:
#         return False
 
# print("Given Word is palindrome? ",is_palindrome("level"))

# Alternative approach, much shorter

def is_palindrome(word):
    return word == word[::-1]

print("Given word is palindrome? ", is_palindrome("Ammar"))
print("Given word is palindrome? ", is_palindrome("racecar"))
# Out:
# Given word is palindrome?  False
# Given word is palindrome?  True

# %%
# Question: Write a function max_of_three(a, b, c) that returns the largest of three numbers.

# Using the max function

def max_of_three(a, b, c):
    largest = max(a, b, c)
    return largest

print(max_of_three(10,14,2))

# alternative code

def max_of_three_alt(a, b, c):
    return max(a, b, c)
print(max_of_three_alt(1,50,40))

# Alternative approach, using conditionals

def max_of_three_alt1(x, y, z):
    if x>y and x>z:
        print("Greatest number is: ", x)
    elif y>x and y>z:
        print("Greatest number is: ", y)
    else:
        print("Greatest number is: ", z)
        
max_of_three_alt1(200,50,300)
# Out:
# 14
# 50
# Greatest number is:  300

# %%
# Question: Write a function grade_marks(marks) that returns:

# "Pass" if marks ≥ 40

# "Fail" otherwise

def grade_marks(marks):
    if marks >= 40:
        return "Pass"
    else:
        return "Fail"

grade_marks(10)
# Out:
# 'Fail'

# %%
# Question: Write a function calculate_discount(price, discount_percent) that returns the final price after discount.

def calculate_discount(price, discount_percent):

    # To calculate price after discount, first we divide the percentage/100,
    # then multiply original price by decimal and then subtract the value from original price
    percentage = discount_percent / 100
    total_discount = price * percentage
    final_price = price - total_discount
    return final_price
    
calculate_discount(200,15)
# Out:
# 170.0

# %%
# Question: Write a function is_even_length(text) that returns True if the string length is even.

def is_even_length(text):
    if len(text) % 2 == 0:   # finding modulus(remainder) of text and comparing with zero
        return True
    else:
        return False
is_even_length("ammar")
# Out:
# True

# %%
# Question: Write a function celsius_to_fahrenheit(c) that converts Celsius to Fahrenheit.

# formula = (celsius * 9/5) + 32

def celsius_to_fahrenheit(celsius):
    value_fahrenheit = (celsius * 9/5) + 32
    return value_fahrenheit

celsius_to_fahrenheit(38)
# Out:
# 100.4

# %% [markdown]
# # Practicing Functions using user-input

# %%
# Question: Write a function get_name_length() that asks the user for their name and prints the number of characters.

# One approach of dealing with user-input along with functions
# def get_name_length(name):
#     return len(name)

# length = input("Enter Your name here: ")
# get_name_length(length)

# Another approach

# def get_name_length_alt():
#     name = input("Enter Your name here: ")
#     length = len(name)
#     return length

# get_name_length_alt()

# Another approach

# def get_name_length_alt1():
#     name_length = len(input("Enter Your name here: "))
#     return name_length

# get_name_length_alt1()

# Using .strip() and .replace method to remove any whitespaces

def get_name_length_strip():
    name = input("Enter Your name here: ").strip().replace(" ", "")
    length = len(name)
    return length
get_name_length_strip()
# Out:
# Enter Your name here:  ammar       yasir
# 10

# %%
# Question: Write a function compare_numbers() that asks the user for two numbers and prints which one is greater.
def compare_number():
    a = float(input("a: "))
    b = float(input("b: "))
    if a > b:
        return a
    else:
        return b
compare_number()
# Out:
# a:  2.5
# b:  1.3
# 2.5

# %%
# Question: Write a function check_password() that asks the user to enter a password and checks if it equals "python123".

def check_password():
    password = "python123"
    user_input = input("Enter your password")
    if user_input.lower() == password:   # handling case sensitivity
        print("You are successfully Logged-In")
    else:
        print("Incorrect Password! Try again..")
check_password()
# Out:
# Enter your password PYthon123
# You are successfully Logged-In
